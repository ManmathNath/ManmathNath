# %% [markdown]
# <a href="https://colab.research.google.com/github/ManmathNath/ManmathNath/blob/main/6_train_test_split%20/Train_and_test_split_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#before, we use all the data to test the model but that's not a good startegy so we should train and test by using split method
#sklearn.model_selection.train_test_split
df=pd.read_csv("carprices.csv")
df
plt.scatter(df["Mileage"],df["Sell Price($)"],label="mileage vs price")
plt.legend()
plt.show()
#plt.scatter(df["Age(yrs)"],df["Sell Price],label="Age(yrs) vs price")
x=df[["Mileage","Age(yrs)"]]
y=df["Sell Price($)"]
from sklearn.linear_model import LinearRegression
model=LinearRegression()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)#by using random_state=10  we allow same data set
len(x_train)
x_train
model.fit(x_train,y_train)
model.predict(x_train)
y_train
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
y_train
# Out:
# 16    35500
# 18    12800
# 1     34000
# 5     26750
# 4     31500
# 11    19500
# 17    19700
# 14    19400
# 13    27500
# 9     22000
# 0     18000
# 7     19300
# 3     40000
# 15    35000
# 10    18700
# 2     26100
# Name: Sell Price($), dtype: int64
